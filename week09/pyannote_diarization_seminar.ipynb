# %%
# 11Gb
# !git clone https://github.com/pyannote/AMI-diarization-setup/
# !cd AMI-diarization-setup/pyannote && sh download_ami.sh
# Out:
# IS1000b.Mix-Headset 100%[++++++++++++++++===>]  71,52M  14,2MB/s    за 0,8s
# 2025-11-05 12:00:43 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1000b/audio/IS1000b.Mix-Headset.wav [74997452/74997452] -> "amicorpus/IS1000b/audio/IS1000b.Mix-Headset.wav" [1]
# IS1000c.Mix-Headset 100%[===================>]  64,52M  23,2MB/s    за 2,8s
# 2025-11-05 12:00:47 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1000c/audio/IS1000c.Mix-Headset.wav [67657772/67657772] -> "amicorpus/IS1000c/audio/IS1000c.Mix-Headset.wav" [1]
# IS1000d.Mix-Headset 100%[===================>]  79,91M  14,6MB/s    за 5,8s
# 2025-11-05 12:00:53 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1000d/audio/IS1000d.Mix-Headset.wav [83786786/83786786] -> "amicorpus/IS1000d/audio/IS1000d.Mix-Headset.wav" [1]
# IS1001a.Mix-Headset 100%[===================>]  27,74M  18,8MB/s    за 1,5s
# 2025-11-05 12:00:55 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1001a/audio/IS1001a.Mix-Headset.wav [29089836/29089836] -> "amicorpus/IS1001a/audio/IS1001a.Mix-Headset.wav" [1]
# IS1001b.Mix-Headset 100%[+==================>]  64,60M  21,0MB/s    за 2,9s
# 2025-11-05 12:00:58 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1001b/audio/IS1001b.Mix-Headset.wav [67734230/67734230] -> "amicorpus/IS1001b/audio/IS1001b.Mix-Headset.wav" [1]
# IS1001c.Mix-Headset 100%[===================>]  44,11M  20,3MB/s    за 2,2s
# 2025-11-05 12:01:01 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1001c/audio/IS1001c.Mix-Headset.wav [46254806/46254806] -> "amicorpus/IS1001c/audio/IS1001c.Mix-Headset.wav" [1]
# IS1001d.Mix-Headset 100%[===================>]  23,83M  16,3MB/s    за 1,5s
# 2025-11-05 12:01:03 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1001d/audio/IS1001d.Mix-Headset.wav [24991104/24991104] -> "amicorpus/IS1001d/audio/IS1001d.Mix-Headset.wav" [1]
# IS1002b.Mix-Headset 100%[===================>]  72,25M  4,21MB/s    за 12s
# 2025-11-05 12:01:15 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1002b/audio/IS1002b.Mix-Headset.wav [75765426/75765426] -> "amicorpus/IS1002b/audio/IS1002b.Mix-Headset.wav" [1]
# IS1002c.Mix-Headset 100%[===================>]  63,50M   862KB/s    за 1m 49s
# 2025-11-05 12:03:05 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1002c/audio/IS1002c.Mix-Headset.wav [66588093/66588093] -> "amicorpus/IS1002c/audio/IS1002c.Mix-Headset.wav" [1]
# IS1002d.Mix-Headset 100%[===================>]  38,54M  22,3MB/s    за 1,7s
# 2025-11-05 12:03:07 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1002d/audio/IS1002d.Mix-Headset.wav [40416640/40416640] -> "amicorpus/IS1002d/audio/IS1002d.Mix-Headset.wav" [1]
# IS1003a.Mix-Headset 100%[===================>]  27,88M  18,2MB/s    за 1,5s
# 2025-11-05 12:03:09 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1003a/audio/IS1003a.Mix-Headset.wav [29231830/29231830] -> "amicorpus/IS1003a/audio/IS1003a.Mix-Headset.wav" [1]
# IS1003b.Mix-Headset 100%[===================>]  50,23M  15,9MB/s    за 3,3s
# 2025-11-05 12:03:13 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1003b/audio/IS1003b.Mix-Headset.wav [52673427/52673427] -> "amicorpus/IS1003b/audio/IS1003b.Mix-Headset.wav" [1]
# IS1003c.Mix-Headset 100%[===================>]  57,26M  10,7MB/s    за 5,7s
# 2025-11-05 12:03:19 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1003c/audio/IS1003c.Mix-Headset.wav [60044093/60044093] -> "amicorpus/IS1003c/audio/IS1003c.Mix-Headset.wav" [1]
# IS1003d.Mix-Headset 100%[===================>]  64,10M  18,8MB/s    за 3,8s
# 2025-11-05 12:03:24 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1003d/audio/IS1003d.Mix-Headset.wav [67217427/67217427] -> "amicorpus/IS1003d/audio/IS1003d.Mix-Headset.wav" [1]
# IS1004a.Mix-Headset 100%[===================>]  24,32M  8,37MB/s    за 2,9s
# 2025-11-05 12:03:27 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1004a/audio/IS1004a.Mix-Headset.wav [25500093/25500093] -> "amicorpus/IS1004a/audio/IS1004a.Mix-Headset.wav" [1]
# IS1004b.Mix-Headset 100%[===================>]  66,58M  12,6MB/s    за 6,0s
# 2025-11-05 12:03:34 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1004b/audio/IS1004b.Mix-Headset.wav [69814759/69814759] -> "amicorpus/IS1004b/audio/IS1004b.Mix-Headset.wav" [1]
# IS1004c.Mix-Headset 100%[===================>]  69,09M  14,4MB/s    за 6,0s
# 2025-11-05 12:03:40 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1004c/audio/IS1004c.Mix-Headset.wav [72444093/72444093] -> "amicorpus/IS1004c/audio/IS1004c.Mix-Headset.wav" [1]
# IS1004d.Mix-Headset 100%[===================>]  59,98M  16,2MB/s    за 4,2s
# 2025-11-05 12:03:45 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1004d/audio/IS1004d.Mix-Headset.wav [62892093/62892093] -> "amicorpus/IS1004d/audio/IS1004d.Mix-Headset.wav" [1]
# IS1005a.Mix-Headset 100%[===================>]  31,28M  9,90MB/s    за 3,2s
# 2025-11-05 12:03:49 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1005a/audio/IS1005a.Mix-Headset.wav [32796093/32796093] -> "amicorpus/IS1005a/audio/IS1005a.Mix-Headset.wav" [1]
# IS1005b.Mix-Headset 100%[===================>]  66,59M  11,3MB/s    за 6,2s
# 2025-11-05 12:03:55 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1005b/audio/IS1005b.Mix-Headset.wav [69825427/69825427] -> "amicorpus/IS1005b/audio/IS1005b.Mix-Headset.wav" [1]
# IS1005c.Mix-Headset 100%[===================>]  62,87M  14,4MB/s    за 4,9s
# 2025-11-05 12:04:01 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1005c/audio/IS1005c.Mix-Headset.wav [65926759/65926759] -> "amicorpus/IS1005c/audio/IS1005c.Mix-Headset.wav" [1]
# IS1006a.Mix-Headset 100%[===================>]  25,96M  10,5MB/s    за 2,5s
# 2025-11-05 12:04:04 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1006a/audio/IS1006a.Mix-Headset.wav [27222759/27222759] -> "amicorpus/IS1006a/audio/IS1006a.Mix-Headset.wav" [1]
# IS1006b.Mix-Headset 100%[===================>]  65,92M  12,3MB/s    за 5,8s
# 2025-11-05 12:04:10 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1006b/audio/IS1006b.Mix-Headset.wav [69124140/69124140] -> "amicorpus/IS1006b/audio/IS1006b.Mix-Headset.wav" [1]
# IS1006c.Mix-Headset 100%[===================>]  59,52M  14,0MB/s    за 4,7s
# 2025-11-05 12:04:16 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS
URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1009b/audio/IS1009b.Mix-Headset.wav [65676093/65676093] -> "amicorpus/IS1009b/audio/IS1009b.Mix-Headset.wav" [1]
# IS1009c.Mix-Headset 100%[===================>]  55,57M  14,9MB/s    за 4,1s
# 2025-11-05 12:05:13 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1009c/audio/IS1009c.Mix-Headset.wav [58268093/58268093] -> "amicorpus/IS1009c/audio/IS1009c.Mix-Headset.wav" [1]
# IS1009d.Mix-Headset 100%[===================>]  59,34M  14,4MB/s    за 4,5s
# 2025-11-05 12:05:18 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IS1009d/audio/IS1009d.Mix-Headset.wav [62225427/62225427] -> "amicorpus/IS1009d/audio/IS1009d.Mix-Headset.wav" [1]
# TS3003a.Mix-Headset 100%[===================>]  45,95M  16,8MB/s    за 2,7s
# 2025-11-05 12:05:21 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS3003a/audio/TS3003a.Mix-Headset.wav [48180608/48180608] -> "amicorpus/TS3003a/audio/TS3003a.Mix-Headset.wav" [1]
# TS3003b.Mix-Headset 100%[===================>]  67,45M  13,4MB/s    за 5,3s
# 2025-11-05 12:05:27 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS3003b/audio/TS3003b.Mix-Headset.wav [70729772/70729772] -> "amicorpus/TS3003b/audio/TS3003b.Mix-Headset.wav" [1]
# TS3003c.Mix-Headset 100%[===================>]  78,43M  13,9MB/s    за 6,8s
# 2025-11-05 12:05:34 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS3003c/audio/TS3003c.Mix-Headset.wav [82240044/82240044] -> "amicorpus/TS3003c/audio/TS3003c.Mix-Headset.wav" [1]
# TS3003d.Mix-Headset 100%[===================>]  79,90M  14,6MB/s    за 5,9s
# 2025-11-05 12:05:40 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS3003d/audio/TS3003d.Mix-Headset.wav [83782444/83782444] -> "amicorpus/TS3003d/audio/TS3003d.Mix-Headset.wav" [1]
# TS3004a.Mix-Headset 100%[===================>]  41,06M  12,6MB/s    за 3,4s
# 2025-11-05 12:05:44 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS3004a/audio/TS3004a.Mix-Headset.wav [43050368/43050368] -> "amicorpus/TS3004a/audio/TS3004a.Mix-Headset.wav" [1]
# TS3004b.Mix-Headset 100%[===================>]  68,54M  10,7MB/s    за 6,5s
# 2025-11-05 12:05:51 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS3004b/audio/TS3004b.Mix-Headset.wav [71873920/71873920] -> "amicorpus/TS3004b/audio/TS3004b.Mix-Headset.wav" [1]
# TS3004c.Mix-Headset 100%[===================>]  90,64M  16,8MB/s    за 5,9s
# 2025-11-05 12:05:58 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS3004c/audio/TS3004c.Mix-Headset.wav [95040044/95040044] -> "amicorpus/TS3004c/audio/TS3004c.Mix-Headset.wav" [1]
# TS3004d.Mix-Headset 100%[===================>]  83,95M  13,7MB/s    за 6,5s
# 2025-11-05 12:06:05 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS3004d/audio/TS3004d.Mix-Headset.wav [88025644/88025644] -> "amicorpus/TS3004d/audio/TS3004d.Mix-Headset.wav" [1]
# TS3005a.Mix-Headset 100%[===================>]  40,25M  11,9MB/s    за 3,7s
# 2025-11-05 12:06:09 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS3005a/audio/TS3005a.Mix-Headset.wav [42203180/42203180] -> "amicorpus/TS3005a/audio/TS3005a.Mix-Headset.wav" [1]
# TS3005b.Mix-Headset 100%[===================>]  74,46M  9,91MB/s    за 7,9s
# 2025-11-05 12:06:18 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/TS
URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2002b/audio/EN2002b.Mix-Headset.wav [57179180/57179180] -> "amicorpus/EN2002b/audio/EN2002b.Mix-Headset.wav" [1]
# EN2002c.Mix-Headset 100%[===================>]  90,71M  10,2MB/s    за 8,5s
# 2025-11-05 12:12:17 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2002c/audio/EN2002c.Mix-Headset.wav [95112236/95112236] -> "amicorpus/EN2002c/audio/EN2002c.Mix-Headset.wav" [1]
# EN2002d.Mix-Headset 100%[===================>]  67,44M  11,9MB/s    за 6,4s
# 2025-11-05 12:12:24 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2002d/audio/EN2002d.Mix-Headset.wav [70716802/70716802] -> "amicorpus/EN2002d/audio/EN2002d.Mix-Headset.wav" [1]
# EN2003a.Mix-Headset 100%[===================>]  68,37M  11,1MB/s    за 6,6s
# 2025-11-05 12:12:31 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2003a/audio/EN2003a.Mix-Headset.wav [71688920/71688920] -> "amicorpus/EN2003a/audio/EN2003a.Mix-Headset.wav" [1]
# EN2004a.Mix-Headset 100%[===================>] 105,15M  12,7MB/s    за 9,2s
# 2025-11-05 12:12:40 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2004a/audio/EN2004a.Mix-Headset.wav [110261634/110261634] -> "amicorpus/EN2004a/audio/EN2004a.Mix-Headset.wav" [1]
# EN2005a.Mix-Headset 100%[===================>] 165,26M  14,2MB/s    за 12s
# 2025-11-05 12:12:53 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2005a/audio/EN2005a.Mix-Headset.wav [173287554/173287554] -> "amicorpus/EN2005a/audio/EN2005a.Mix-Headset.wav" [1]
# EN2006a.Mix-Headset 100%[===================>] 107,59M  12,7MB/s    за 9,2s
# 2025-11-05 12:13:04 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2006a/audio/EN2006a.Mix-Headset.wav [112815832/112815832] -> "amicorpus/EN2006a/audio/EN2006a.Mix-Headset.wav" [1]
# EN2006b.Mix-Headset 100%[===================>]  93,15M  14,4MB/s    за 6,8s
# 2025-11-05 12:13:11 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2006b/audio/EN2006b.Mix-Headset.wav [97672322/97672322] -> "amicorpus/EN2006b/audio/EN2006b.Mix-Headset.wav" [1]
# EN2009b.Mix-Headset 100%[===================>]  75,51M  14,9MB/s    за 5,6s
# 2025-11-05 12:13:17 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2009b/audio/EN2009b.Mix-Headset.wav [79177090/79177090] -> "amicorpus/EN2009b/audio/EN2009b.Mix-Headset.wav" [1]
# EN2009c.Mix-Headset 100%[===================>]  94,60M  12,8MB/s    за 7,8s
# 2025-11-05 12:13:25 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2009c/audio/EN2009c.Mix-Headset.wav [99199704/99199704] -> "amicorpus/EN2009c/audio/EN2009c.Mix-Headset.wav" [1]
# EN2009d.Mix-Headset 100%[===================>] 162,49M  12,0MB/s    за 14s
# 2025-11-05 12:13:39 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2009d/audio/EN2009d.Mix-Headset.wav [170379992/170379992] -> "amicorpus/EN2009d/audio/EN2009d.Mix-Headset.wav" [1]
# IB4001.Mix-Headset. 100%[===================>]  54,34M  14,1MB/s    за 4,3s
# 2025-11-05 12:13:44 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IB
URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IN1012/audio/IN1012.Mix-Headset.wav [99485912/99485912] -> "amicorpus/IN1012/audio/IN1012.Mix-Headset.wav" [1]
# IN1013.Mix-Headset. 100%[===================>]  95,89M  9,32MB/s    за 10s
# 2025-11-05 12:15:30 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IN1013/audio/IN1013.Mix-Headset.wav [100548140/100548140] -> "amicorpus/IN1013/audio/IN1013.Mix-Headset.wav" [1]
# IN1014.Mix-Headset. 100%[===================>] 112,70M  8,36MB/s    за 13s
# 2025-11-05 12:15:44 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IN1014/audio/IN1014.Mix-Headset.wav [118171864/118171864] -> "amicorpus/IN1014/audio/IN1014.Mix-Headset.wav" [1]
# IN1016.Mix-Headset. 100%[===================>] 109,99M  9,37MB/s    за 11s
# 2025-11-05 12:15:56 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IN1016/audio/IN1016.Mix-Headset.wav [115337432/115337432] -> "amicorpus/IN1016/audio/IN1016.Mix-Headset.wav" [1]
# Fixing wav files with invalid chunks
# amicorpus/IS1004d/audio/IS1004d.Mix-Headset.wav has been properly reformated
# amicorpus/IS1006c/audio/IS1006c.Mix-Headset.wav has been properly reformated
# amicorpus/IS1008d/audio/IS1008d.Mix-Headset.wav has been properly reformated
# amicorpus/IS1007a/audio/IS1007a.Mix-Headset.wav has been properly reformated
# amicorpus/IS1008c/audio/IS1008c.Mix-Headset.wav has been properly reformated
# amicorpus/IS1005a/audio/IS1005a.Mix-Headset.wav has been properly reformated
# amicorpus/IS1008b/audio/IS1008b.Mix-Headset.wav has been properly reformated
# amicorpus/IS1009b/audio/IS1009b.Mix-Headset.wav has been properly reformated
# amicorpus/IS1002c/audio/IS1002c.Mix-Headset.wav has been properly reformated
# amicorpus/IS1004b/audio/IS1004b.Mix-Headset.wav has been properly reformated
# amicorpus/IS1008a/audio/IS1008a.Mix-Headset.wav has been properly reformated
# amicorpus/IS1004a/audio/IS1004a.Mix-Headset.wav has been properly reformated
# amicorpus/IS1005b/audio/IS1005b.Mix-Headset.wav has been properly reformated
# amicorpus/IS1007c/audio/IS1007c.Mix-Headset.wav has been properly reformated
# amicorpus/IS1004c/audio/IS1004c.Mix-Headset.wav has been properly reformated
# amicorpus/IS1009c/audio/IS1009c.Mix-Headset.wav has been properly reformated
# amicorpus/IS1003c/audio/IS1003c.Mix-Headset.wav has been properly reformated
# amicorpus/IS1009a/audio/IS1009a.Mix-Headset.wav has been properly reformated
# amicorpus/IS1009d/audio/IS1009d.Mix-Headset.wav has been properly reformated
# amicorpus/IS1006a/audio/IS1006a.Mix-Headset.wav has been properly reformated
# amicorpus/IS1005c/audio/IS1005c.Mix-Headset.wav has been properly reformated
# amicorpus/IS1006d/audio/IS1006d.Mix-Headset.wav has been properly reformated
# amicorpus/IS1003d/audio/IS1003d.Mix-Headset.wav has been properly reformated
# amicorpus/IS1007b/audio/IS1007b.Mix-Headset.wav has been properly reformated

# %%
import os
from typing import List

os.environ["PYANNOTE_DATABASE_CONFIG"] = "AMI-diarization-setup/pyannote/database.yml"

import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
import pyaudio
import soundfile
import torch
from pyannote.audio import Model
from pyannote.audio.models.segmentation import PyanNet
from pyannote.audio.pipelines import (
    VoiceActivityDetection as VoiceActivityDetectionPipeline,
)
from pyannote.audio.tasks import VoiceActivityDetection
from pyannote.database import FileFinder, get_protocol

# %% [markdown]
# **RTTM**: **R**ich **T**ranscription **T**ime **M**arked
#
# \<type> \<file> \<chnl> \<tbeg> \<tdur> \<ortho> \<stype> \<name> \<conf> \<slat>

# %%
# !head AMI-diarization-setup/word_and_vocalsounds/rttms/dev/ES2011a.rttm
# Out:
# SPEAKER ES2011a 1 34.27 10.12 <NA> <NA> FEE041 <NA> <NA>
# SPEAKER ES2011a 1 46.43 10.42 <NA> <NA> FEE041 <NA> <NA>
# SPEAKER ES2011a 1 58.56 5.72 <NA> <NA> FEE041 <NA> <NA>
# SPEAKER ES2011a 1 65.0 12.78 <NA> <NA> FEE044 <NA> <NA>
# SPEAKER ES2011a 1 77.04 3.75 <NA> <NA> FEE041 <NA> <NA>
# SPEAKER ES2011a 1 78.93 3.96 <NA> <NA> FEE044 <NA> <NA>
# SPEAKER ES2011a 1 82.98 6.26 <NA> <NA> FEE041 <NA> <NA>
# SPEAKER ES2011a 1 84.791 0.781 <NA> <NA> FEE042 <NA> <NA>
# SPEAKER ES2011a 1 85.808 0.857 <NA> <NA> FEE043 <NA> <NA>
# SPEAKER ES2011a 1 89.02 4.08 <NA> <NA> FEE043 <NA> <NA>

# %%
# !cat AMI-diarization-setup/pyannote/database.yml
# Out:
# Databases:
#   # tell pyannote.database where to find AMI wav files.
#   # {uri} is a placeholder for the session name (eg. ES2004c).
#   # you might need to update this line to fit your own setup.
#   AMI: amicorpus/{uri}/audio/{uri}.Mix-Headset.wav
#   AMI-SDM: amicorpus/{uri}/audio/{uri}.Array1-01.wav
#
# Protocols:
#
#   AMI-SDM:
#     SpeakerDiarization:
#       only_words:
#         train:
#             uri: ../lists/train.meetings.txt
#             annotation: ../only_words/rttms/train/{uri}.rttm
#             annotated: ../uems/train/{uri}.uem
#         development:
#             uri: ../lists/dev.meetings.txt
#             annotation: ../only_words/rttms/dev/{uri}.rttm
#             annotated: ../uems/dev/{uri}.uem
#         test:
#             uri: ../lists/test.meetings.txt
#             annotation: ../only_words/rttms/test/{uri}.rttm
#             annotated: ../uems/test/{uri}.uem
#       mini:
#         train:
#           uri: ../lists/train.mini.txt
#           annotation: ../only_words/rttms/train/{uri}.rttm
#           annotated: ../uems/train/{uri}.uem
#         development:
#           uri: ../lists/dev.mini.txt
#           annotation: ../only_words/rttms/dev/{uri}.rttm
#           annotated: ../uems/dev/{uri}.uem
#         test:
#           uri: ../lists/test.mini.txt
#           annotation: ../only_words/rttms/test/{uri}.rttm
#           annotated: ../uems/test/{uri}.uem
#
#   AMI:
#     SpeakerDiarization:
#       only_words:
#         train:
#             uri: ../lists/train.meetings.txt
#             annotation: ../only_words/rttms/train/{uri}.rttm
#             annotated: ../uems/train/{uri}.uem
#         development:
#             uri: ../lists/dev.meetings.txt
#             annotation: ../only_words/rttms/dev/{uri}.rttm
#             annotated: ../uems/dev/{uri}.uem
#         test:
#             uri: ../lists/test.meetings.txt
#             annotation: ../only_words/rttms/test/{uri}.rttm
#             annotated: ../uems/test/{uri}.uem
#
#       mini:
#         train:
#           uri: ../lists/train.mini.txt
#           annotation: ../only_words/rttms/train/{uri}.rttm
#           annotated: ../uems/train/{uri}.uem
#         development:
#           uri: ../lists/dev.mini.txt
#           annotation: ../only_words/rttms/dev/{uri}.rttm
#           annotated: ../uems/dev/{uri}.uem
#         test:
#           uri: ../lists/test.mini.txt
#           annotation: ../only_words/rttms/test/{uri}.rttm
#           annotated: ../uems/test/{uri}.uem
#
#       word_and_vocalsounds:
#         train:
#             uri: ../lists/train.meetings.txt
#             annotation: ../word_and_vocalsounds/rttms/train/{uri}.rttm
#             annotated: ../uems/train/{uri}.uem
#         development:
#             uri: ../lists/dev.meetings.txt
#             annotation: ../word_and_vocalsounds/rttms/dev/{uri}.rttm
#             annotated: ../uems/dev/{uri}.uem
#         test:
#             uri: ../lists/test.meetings.txt
#             annotation: ../word_and_vocalsounds/rttms/test/{uri}.rttm
#             annotated: ../uems/test/{uri}.uem

# %%
ami = get_protocol(
    "AMI.SpeakerDiarization.only_words", preprocessors={"audio": FileFinder()}
)

# %% [markdown]
# # Voice Activity Detection

# %%
vad_task = VoiceActivityDetection(ami, duration=2.0, batch_size=128)
vad_model = PyanNet(
    task=vad_task,
    sincnet={"stride": 100},
    lstm={"hidden_size": 32, "num_layers": 2, "bidirectional": True},
    linear={"hidden_size": 32, "num_layers": 2},
)
# Out:
# Protocol AMI.SpeakerDiarization.only_words does not precompute the output of torchaudio.info(): adding a 'torchaudio.info' preprocessor for you to speed up dataloaders. See pyannote.database documentation on how to do that yourself.
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pyannote/audio/core/task.py:246: UserWarning: num_workers > 0 is not supported with macOS and Python 3.8+: setting num_workers = 0.
#   warnings.warn(

# %%
vad_model
# Out:
# PyanNet(
#   (sincnet): SincNet(
#     (wav_norm1d): InstanceNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (conv1d): ModuleList(
#       (0): Encoder(
#         (filterbank): ParamSincFB()
#       )
#       (1): Conv1d(80, 60, kernel_size=(5,), stride=(1,))
#       (2): Conv1d(60, 60, kernel_size=(5,), stride=(1,))
#     )
#     (pool1d): ModuleList(
#       (0-2): 3 x MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     )
#     (norm1d): ModuleList(
#       (0): InstanceNorm1d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (1-2): 2 x InstanceNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (lstm): LSTM(60, 32, num_layers=2, batch_first=True, bidirectional=True)
#   (linear): ModuleList(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): Linear(in_features=32, out_features=32, bias=True)
#   )
# )

# %%
import pytorch_lightning as pl


trainer = pl.Trainer(accelerator="cpu", max_epochs=2)
trainer.fit(vad_model)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
#
#   | Name              | Type             | Params | Mode  | In sizes      | Out sizes
# -------------------------------------------------------------------------------------------------------------------------
# 0 | sincnet           | SincNet          | 42.6 K | train | [1, 1, 32000] | [1, 60, 10]
# 1 | lstm              | LSTM             | 49.2 K | train | [1, 10, 60]   | [[1, 10, 64], [[4, 1, 32], [4, 1, 32]]]
# 2 | linear            | ModuleList       | 3.1 K  | train | ?             | ?
# 3 | classifier        | Linear           | 33     | train | [1, 10, 32]   | [1, 10, 1]
# 4 | activation        | Sigmoid          | 0      | train | [1, 10, 1]    | [1, 10, 1]
# 5 | validation_metric | MetricCollection | 0      | train | ?             | ?
# -------------------------------------------------------------------------------------------------------------------------
# 94.9 K    Trainable params
# 0         Non-trainable params
# 94.9 K    Total params
# 0.380     Total estimated model params size (MB)
# 23        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:433: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:433: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pytorch_lightning/utilities/data.py:123: Your `IterableDataset` has `__len__` defined. In combination with multi-process data loading (when num_workers > 1), `__len__` could be inaccurate if each worker is not configured independently to avoid having duplicate data.
# Epoch 0:   0%|          | 0/1270 [00:00<?, ?it/s]
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/torch_audiomentations/core/transforms_interface.py:221: UserWarning: target_rate is required by Identity. It has been automatically inferred from targets shape to 5. If this is incorrect, you can pass it directly.
#   warnings.warn(
# Epoch 0: 100%|██████████| 1270/1270 [05:53<00:00,  3.60it/s, v_num=0]
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# Epoch 1: 100%|██████████| 1270/1270 [06:22<00:00,  3.32it/s, v_num=0, BinaryAUROC=0.964]
# `Trainer.fit` stopped: `max_epochs=2` reached.
# Epoch 1: 100%|██████████| 1270/1270 [06:22<00:00,  3.32it/s, v_num=0, BinaryAUROC=0.964]

# %%
vad_model = Model.from_pretrained("lightning_logs/version_0/checkpoints/epoch=1-step=2540.ckpt")

# %%
def create_stream(
    pyaudio_manager,
    sample_rate: int = 16_000,
    frames_per_buffer: int = 1600,
):
    return pyaudio_manager.open(
        format=pyaudio.paInt16,
        channels=1,
        rate=sample_rate,
        input=True,
        frames_per_buffer=frames_per_buffer,
    )


def record_audio_chunk(stream, duration_seconds: float = 0.1) -> np.ndarray:
    frames_to_read = int(stream._rate * duration_seconds)
    byte_frames: bytes = stream.read(frames_to_read, exception_on_overflow=False)
    audio_frame = np.frombuffer(byte_frames, dtype=np.int16)
    float_audio_frame = audio_frame / (1 << 15)
    return float_audio_frame

# %%
SR = 16_000


def record_audio(duration=8, chunk_duration=0.1):
    pa_manager = pyaudio.PyAudio()
    stream = create_stream(pa_manager, sample_rate=SR)

    frames = []

    while len(frames) < duration / chunk_duration:
        audio_frames = record_audio_chunk(stream, duration_seconds=chunk_duration)
        frames.append(audio_frames)

    return np.concatenate(frames)


wav = record_audio()

ipd.display(ipd.Audio(wav, rate=SR))
plt.figure(figsize=(12, 4))
plt.plot(np.arange(wav.size) / SR, wav)
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
WINDOW_SIZE = 2 * SR
STRIDE = 2 * SR // 10
RESOLUTION = STRIDE / SR


def window_infernece(model, wav, window_size=32000, window_shift=32000):

    assert STRIDE <= window_shift <= window_size

    model.eval()

    start = 0

    probs = []

    windows = window_size // window_shift

    vad_probs = (-1e-3) * np.ones(
        (
            wav.size // window_size * (window_size // window_shift) + 1,
            wav.size // STRIDE,
        )
    )
    prev_padding = 0
    i = 0

    while start <= wav.size - window_size:
        wav_tensor = (
            torch.from_numpy(wav[start : start + window_size])
            .to(torch.float32)
            .reshape(1, 1, -1)
        )

        with torch.no_grad():
            out = vad_model(wav_tensor)

        out_probs = out.squeeze(0, 2).numpy()

        padded_out_probs = np.pad(
            out_probs,
            pad_width=(
                prev_padding,
                vad_probs.shape[1] - prev_padding - out_probs.size,
            ),
            constant_values=(-1,),
        )

        vad_probs[i, :] = padded_out_probs

        prev_padding += window_shift // STRIDE
        start += window_shift
        i += 1

    return np.array(
        [
            np.median(vad_probs[:, j][vad_probs[:, j] > -1e-3])
            for j in range(vad_probs.shape[1])
        ]
    )


min_duration = 0
max_duration = 8
min_frames = int(min_duration * SR)
max_frames = int(max_duration * SR)

threshold = 0.3

# %%
smoothed_vad_probs = window_infernece(
    vad_model, wav, window_size=32_000, window_shift=3_200
)

# %%
ipd.display(ipd.Audio(wav[min_frames:max_frames], rate=SR))

fig, ax1 = plt.subplots()

color = "cornflowerblue"
ax1.set_xlabel("time (s)")
ax1.set_ylabel("waveform", color=color)
ax1.plot(
    np.arange(min_frames, max_frames) / SR, wav[min_frames:max_frames], color=color
)
ax1.tick_params(axis="y", labelcolor=color)

ax2 = ax1.twinx()

color = "gold"
ax2.set_ylabel("VAD proba", color=color)
ax2.plot(
    [(i + 0.5) * RESOLUTION for i in range(smoothed_vad_probs.size)],
    smoothed_vad_probs,
    color=color,
)
ax2.tick_params(axis="y", labelcolor=color)
ax2.set_ylim(0, 1)
fig.tight_layout()
plt.savefig("VAD_result.png", dpi=300)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav, _ = soundfile.read("./data/speech_with_music.wav")

speech_segments = [
    (1, 1.8),
    (2.2, 2.7),
    (3.4, 3.8),
    (4.5, 5.1),
    (5.5, 6),
]

smoothed_vad_probs = window_infernece(
    vad_model, wav, window_size=32_000, window_shift=3_200
)

# %%
def find_segments(predictions: List[bool]) -> List[List[int]]:
    prev = False
    pred_segments = []
    for i, point in enumerate(predictions):
        if point:
            if prev:
                pred_segments[-1][1] = i
            else:
                pred_segments.append([i, i])
                prev = True
        else:
            prev = False

    return pred_segments


predicted_segments = find_segments(smoothed_vad_probs > threshold)

# %%
plt.figure(figsize=(12, 3))

for i, (start_time, end_time) in enumerate(speech_segments):
    label = "speech" if i == 0 else None
    plt.axvspan(start_time, end_time, color="red", alpha=0.3, label=label)

plt.plot(np.arange(wav.size) / SR, wav)
plt.legend()
plt.axis("off")
plt.show()

plt.figure(figsize=(12, 3))

for i, (start_frame, end_frame) in enumerate(predicted_segments):
    label = "predicted" if i == 0 else None
    plt.axvspan(
        start_frame * RESOLUTION,
        end_frame * RESOLUTION,
        color="gold",
        alpha=0.3,
        label=label,
    )
plt.plot(np.arange(wav.size) / SR, wav)
plt.legend()
plt.axis("off")
plt.savefig("VAD_prediction.png", dpi=300)

# %%
soundfile.write("data/whisper_with_music.wav", data=wav, samplerate=SR)

# %%
hyper_params = {
    "onset": 0.6,
    "offset": 0.4,
    "min_duration_on": 0.0,
    "min_duration_off": 0.0,
}

pipeline = VoiceActivityDetectionPipeline(segmentation=vad_model)

pipeline.instantiate(hyper_params)

# %%
res = pipeline("./data/whisper_with_music.wav")

# %%
res

# %% [markdown]
# # Speaker Segmentation

# %%
from pyannote.audio.tasks import SpeakerDiarization

seg_task = SpeakerDiarization(ami, duration=4.0, max_num_speakers=4, batch_size=64)

sd_model = PyanNet(
    task=seg_task, sincnet={"stride": 105},
    lstm={"hidden_size": 32, "num_layers": 2, "bidirectional": True},
    linear={"hidden_size": 32, "num_layers": 2},
)

trainer = pl.Trainer(accelerator="cpu", max_epochs=5)
trainer.fit(sd_model)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pyannote/audio/core/task.py:246: UserWarning: num_workers > 0 is not supported with macOS and Python 3.8+: setting num_workers = 0.
#   warnings.warn(
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pyannote/audio/tasks/segmentation/speaker_diarization.py:165: UserWarning: `max_num_speakers` has been deprecated in favor of `max_speakers_per_chunk`.
#   warnings.warn(
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
#
#   | Name              | Type             | Params | Mode  | In sizes      | Out sizes
# -------------------------------------------------------------------------------------------------------------------------
# 0 | sincnet           | SincNet          | 42.6 K | train | [1, 1, 64000] | [1, 60, 20]
# 1 | lstm              | LSTM             | 49.2 K | train | [1, 20, 60]   | [[1, 20, 64], [[4, 1, 32], [4, 1, 32]]]
# 2 | linear            | ModuleList       | 3.1 K  | train | ?             | ?
# 3 | classifier        | Linear           | 132    | train | [1, 20, 32]   | [1, 20, 4]
# 4 | activation        | Sigmoid          | 0      | train | [1, 20, 4]    | [1, 20, 4]
# 5 | validation_metric | MetricCollection | 0      | train | ?             | ?
# -------------------------------------------------------------------------------------------------------------------------
# 95.0 K    Trainable params
# 0         Non-trainable params
# 95.0 K    Total params
# 0.380     Total estimated model params size (MB)
# 27        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:433: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:433: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/pytorch_lightning/utilities/data.py:123: Your `IterableDataset` has `__len__` defined. In combination with multi-process data loading (when num_workers > 1), `__len__` could be inaccurate if each worker is not configured independently to avoid having duplicate data.
# Epoch 0:   0%|          | 0/1270 [00:00<?, ?it/s]
# /opt/homebrew/Caskroom/miniforge/base/envs/voice_course3.11/lib/python3.11/site-packages/torch_audiomentations/core/transforms_interface.py:221: UserWarning: target_rate is required by Identity. It has been automatically inferred from targets shape to 5. If this is incorrect, you can pass it directly.
#   warnings.warn(
# Epoch 4: 100%|██████████| 1270/1270 [05:47<00:00,  3.65it/s, v_num=1, DiarizationErrorRate=0.230, DiarizationErrorRate/Confusion=0.0466, DiarizationErrorRate/FalseAlarm=0.0606, DiarizationErrorRate/Miss=0.123, DiarizationErrorRate/Threshold=0.560]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 1270/1270 [05:47<00:00,  3.65it/s, v_num=1, DiarizationErrorRate=0.230, DiarizationErrorRate/Confusion=0.0466, DiarizationErrorRate/FalseAlarm=0.0606, DiarizationErrorRate/Miss=0.123, DiarizationErrorRate/Threshold=0.560]

# %%
sd_model = Model.from_pretrained("lightning_logs/version_1/checkpoints/epoch=4-step=6350.ckpt")

# %%
wav = record_audio(duration=12)

# %%
plt.plot(np.arange(wav.size) / SR, wav)

# %%
def diarization_window_infernece(model, wav, window_size=64_000, window_shift=64_000):

    assert STRIDE <= window_shift <= window_size

    model.eval()

    start = 0

    prev_padding = 0
    i = 0

    fig, ax1 = plt.subplots()
    color = "cornflowerblue"
    ax1.set_xlabel("time (s)")
    ax1.set_ylabel("waveform", color=color)
    ax1.plot(np.arange(wav.size) / SR, wav, color=color)
    ax1.tick_params(axis="y", labelcolor=color)
    ax2 = ax1.twinx()

    out_scores = []

    while start <= wav.size - window_size:
        wav_tensor = (
            torch.from_numpy(wav[start : start + window_size])
            .to(torch.float32)
            .reshape(1, 1, -1)
        )

        with torch.no_grad():
            out = model(wav_tensor)

        out_probs = out.squeeze(0).numpy()

        colors = ["gold", "green", "darkorange", "black"]
        for j in range(out_probs.shape[1]):
            ax2.plot(
                [
                    (i + 0.5) * RESOLUTION
                    for i in range(prev_padding, prev_padding + out_probs.shape[0])
                ],
                out_probs[:, j],
                color=colors[j],
            )

        fig.tight_layout()

        prev_padding += window_shift // STRIDE
        start += window_shift
        i += 1
        out_scores.append(out_probs)
    ax2.set_ylabel("Speaker Activity proba")
    ax2.set_ylim(0, 1)
    ax2.tick_params(axis="y")
    plt.show()
    return out_scores

# %%
res = diarization_window_infernece(sd_model, wav)
